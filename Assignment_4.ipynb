# %% [markdown]
# 1. What exactly is []?
# Ans: It is a list

# %% [markdown]
# 2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value?
# (Assume [2, 4, 6, 8, 10] are in spam.)  Ans:

# %%
spam=[2,4,6,8,10]
spam[2]='hello'
spam
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.

# %% [markdown]
# 3. What is the value of spam[int(int('3' * 2) / 11)]?
# Ans:

# %%
spam=['a','b','c','d']
spam[int(int('3'*2)/11)]
# Out:
# 'd'

# %% [markdown]
# 4. What is the value of spam[-1]?
# Ans:

# %%
spam[-1]
# Out:
# 'd'

# %% [markdown]
# 5. What is the value of spam[:2]?
# Ans:

# %%
spam[:2]
# Out:
# ['a', 'b']

# %% [markdown]
# Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.

# %% [markdown]
# 6. What is the value of bacon.index('cat')?
# Ans:

# %%
bacon =[3.14,'cat',11,'cat',True]
bacon.index('cat')
# Out:
# 1

# %% [markdown]
# 7. How does bacon.append(99) change the look of the list value in bacon?
# Ans:

# %%
bacon.append(99)
bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# 8. How does bacon.remove('cat') change the look of the list in bacon?
# Ans:

# %%
bacon.remove('cat')
bacon
# Out:
# [3.14, 11, 'cat', True, 99]

# %% [markdown]
# 9. What are the list concatenation and list replication operators?
# Ans:
# List concatenation operator is '+'
# List replication operator is '*'

# %% [markdown]
# 10. What is difference between the list methods append() and insert()?
# Ans:
# append() method will add the element at the last of the list.
# insert() method we can add element where ever we required so it require 2 arguments such as index and element.

# %% [markdown]
# 11. What are the two methods for removing items from a list?
# Ans:pop(),remove(),clear(),del

# %%
lst=[23,33,53,78,4,22,79]
lst.pop()
# Out:
# 79

# %%
lst.remove(4)
lst
# Out:
# [23, 33, 53, 78, 22]

# %%
del lst[:1]
lst
# Out:
# [33, 53, 78, 22]

# %%
lst.clear()
lst
# Out:
# []

# %% [markdown]
# 12. Describe how list values and string values are identical.
# Ans:
#     List value is enclosed by square bracket and string values are enclosed by single quotes or double quotes.

# %% [markdown]
# 13. What's the difference between tuples and lists?
# Ans: Tuple is enclosed by () and it is immutable.it is faster
#      List is enclosed by []  and it is mutable. It is slower

# %% [markdown]
# 14. How do you type a tuple value that only contains the integer 42?
# Ans: tuple1=(42,)

# %%
tuple1=(42,)
type(tuple1)
# Out:
# tuple

# %% [markdown]
# 15. How do you get a list value's tuple form? How do you get a tuple value's list form?
# Ans: To get a list value tuple form we use tuple() method and to get a tuple value list form is list() method.

# %% [markdown]
# 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
# Ans:It contain List values.

# %%
17. How do you distinguish between copy.copy() and copy.deepcopy()?
Ans:A shallow copy constructs a new compound object and then (to the extent possible) inserts references into it to the objects found in the original.
    copy.copy() is shallow copy
A deep copy constructs a new compound object and then, recursively, inserts copies into it of the objects found in the original.
    copy.deepcopy() is deep copy
